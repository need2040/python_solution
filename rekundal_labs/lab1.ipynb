# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df = pd.read_excel('lab1data.xlsx')

# %%
df
# Out:
#     № варианта  Годы выпуска продукции (t)  Unnamed: 2  Unnamed: 3  \
# 0          NaN                        1.00        2.00        3.00
# 1          1.0                       13.50       12.70       12.00
# 2          2.0                      251.00      249.00      248.00
# 3          3.0                        0.91        0.87        0.85
# 4          4.0                        2.54        2.50        2.45
# 5          5.0                        6.30        6.21        6.15
# 6          6.0                       18.20       17.50       17.10
# 7          7.0                      134.00      130.00      128.00
# 8          8.0                       64.00       61.00       58.00
# 9          9.0                        4.25        4.20        4.18
# 10        10.0                        1.80        1.78        1.70
# 11        11.0                        9.26        9.38       12.11
# 12        12.0                       13.26       10.16       13.72
# ...

# %%
df = df.iloc[7,1:]

# %%
data = df.values

# %%
plt.plot(data)
